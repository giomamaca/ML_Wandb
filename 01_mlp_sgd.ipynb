# %%
import importlib
import src.data, src.models, src.utils, src.train
for _m in (src.data, src.models, src.utils, src.train):
    importlib.reload(_m)

import os
from src.data import get_loaders
from src.models import MLP
from src.utils import check_initial_loss, overfit_small_batch, check_gradients
from src.train import train

CSV = '../train.csv'
print('Using data:', CSV)

Model    = MLP
run_name = '01_mlp_sgd'
config   = {'lr':1e-3,'epochs':30,'optimizer':'sgd'}
augment  = False

tr, va = get_loaders(CSV, batch_size=64, augment_train=False)
print("===== sanity =====")
check_initial_loss(Model(), va)
overfit_small_batch(Model(), tr, steps=200)
check_gradients(Model(), tr)

tr, va = get_loaders(CSV, batch_size=64, augment_train=augment)
print(f"\n===== train {run_name} =====")
train(Model(), tr, va, config, run_name=run_name)
# Out:
# Using data: ../train.csv
# ===== sanity =====
# initial loss = 1.952, expected ~1.946
# step   0 | loss 1.9237 | acc 0.203
# step  50 | loss 0.3875 | acc 0.938
# step 100 | loss 0.0637 | acc 1.000
# step 150 | loss 0.0212 | acc 1.000
# step 199 | loss 0.0107 | acc 1.000
# net.1.weight                             grad norm = 1.765623
# net.1.bias                               grad norm = 0.068748
# net.3.weight                             grad norm = 0.900882
# net.3.bias                               grad norm = 0.182881
#
# ===== train 01_mlp_sgd =====
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from C:\Users\User\_netrc.
# wandb: Currently logged in as: gmama23 (gmama23-free-university-of-tbilisi-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>D:\ML\project4\ML_Wandb\wandb\run-20260615_221206-syq9sepq</code>
# Syncing run <strong><a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments/runs/syq9sepq' target="_blank">01_mlp_sgd</a></strong> to <a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments' target="_blank">https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments</a>
#  View run at <a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments/runs/syq9sepq' target="_blank">https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments/runs/syq9sepq</a>
# epoch  0 | train 1.802/0.254 | val 1.774/0.271 | gap -0.016
# epoch  1 | train 1.757/0.290 | val 1.744/0.317 | gap -0.027
# epoch  2 | train 1.718/0.324 | val 1.703/0.340 | gap -0.016
# epoch  3 | train 1.691/0.343 | val 1.691/0.332 | gap +0.010
# epoch  4 | train 1.670/0.352 | val 1.669/0.355 | gap -0.003
# epoch  5 | train 1.656/0.355 | val 1.658/0.362 | gap -0.007
# epoch  6 | train 1.646/0.360 | val 1.654/0.356 | gap +0.003
# epoch  7 | train 1.637/0.365 | val 1.651/0.359 | gap +0.005
# epoch  8 | train 1.628/0.372 | val 1.640/0.361 | gap +0.010
# epoch  9 | train 1.620/0.373 | val 1.631/0.371 | gap +0.002
# epoch 10 | train 1.611/0.378 | val 1.631/0.374 | gap +0.004
# epoch 11 | train 1.604/0.380 | val 1.623/0.373 | gap +0.007
# epoch 12 | train 1.595/0.384 | val 1.627/0.369 | gap +0.014
# epoch 13 | train 1.588/0.385 | val 1.609/0.381 | gap +0.004
# epoch 14 | train 1.579/0.391 | val 1.602/0.387 | gap +0.004
# epoch 15 | train 1.575/0.391 | val 1.605/0.384 | gap +0.007
# epoch 16 | train 1.567/0.396 | val 1.616/0.382 | gap +0.013
# epoch 17 | train 1.561/0.396 | val 1.610/0.372 | gap +0.024
# epoch 18 | train 1.558/0.399 | val 1.594/0.393 | gap +0.006
# epoch 19 | train 1.550/0.405 | val 1.591/0.387 | gap +0.018
# epoch 20 | train 1.543/0.406 | val 1.587/0.393 | gap +0.014
# epoch 21 | train 1.536/0.408 | val 1.578/0.400 | gap +0.009
# epoch 22 | train 1.531/0.412 | val 1.601/0.378 | gap +0.034
# epoch 23 | train 1.527/0.414 | val 1.605/0.378 | gap +0.036
# epoch 24 | train 1.519/0.418 | val 1.578/0.398 | gap +0.019
# epoch 25 | train 1.514/0.420 | val 1.579/0.389 | gap +0.031
# epoch 26 | train 1.507/0.424 | val 1.595/0.382 | gap +0.042
# epoch 27 | train 1.500/0.429 | val 1.581/0.384 | gap +0.045
# epoch 28 | train 1.495/0.427 | val 1.564/0.408 | gap +0.019
# epoch 29 | train 1.493/0.429 | val 1.582/0.391 | gap +0.039
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>overfit_gap</td><td>▂▁▂▅▃▃▄▄▅▄▄▄▅▄▄▄▅▆▄▅▅▄▇▇▆▇██▆▇</td></tr><tr><td>train_acc</td><td>▁▂▄▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇██████</td></tr><tr><td>train_loss</td><td>█▇▆▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▃▅▄▅▆▅▆▆▆▆▆▆▇▇▇▇▆▇▇▇█▆▆█▇▇▇█▇</td></tr><tr><td>val_loss</td><td>█▇▆▅▄▄▄▄▄▃▃▃▃▃▂▂▃▃▂▂▂▁▂▂▁▁▂▂▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acc_Angry</td><td>0.27569</td></tr><tr><td>acc_Disgust</td><td>0</td></tr><tr><td>acc_Fear</td><td>0.0709</td></tr><tr><td>acc_Happy</td><td>0.7129</td></tr><tr><td>acc_Neutral</td><td>0.43952</td></tr><tr><td>acc_Sad</td><td>0.34161</td></tr><tr><td>acc_Surprise</td><td>0.41956</td></tr><tr><td>best_val_acc</td><td>0.4076</td></tr><tr><td>epoch</td><td>29</td></tr><tr><td>overfit_gap</td><td>0.03884</td></tr><tr><td>+5</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">01_mlp_sgd</strong> at: <a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments/runs/syq9sepq' target="_blank">https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments/runs/syq9sepq</a><br> View project at: <a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments' target="_blank">https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments</a><br>Synced 5 W&B file(s), 1 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260615_221206-syq9sepq\logs</code>
# (MLP(
#    (net): Sequential(
#      (0): Flatten(start_dim=1, end_dim=-1)
#      (1): Linear(in_features=2304, out_features=512, bias=True)
#      (2): ReLU()
#      (3): Linear(in_features=512, out_features=7, bias=True)
#    )
#  ),
#  0.4076011157601116)
