# %%
import importlib
import src.data, src.models, src.utils, src.train
for _m in (src.data, src.models, src.utils, src.train):
    importlib.reload(_m)

import os
from src.data import get_loaders
from src.models import RegularizedCNN
from src.utils import check_initial_loss, overfit_small_batch, check_gradients
from src.train import train

CSV = '../train.csv'

Model    = RegularizedCNN
run_name = '03_regularized_cnn'
config   = {'lr':1e-3,'epochs':30,'optimizer':'adam'}
augment  = False

tr, va = get_loaders(CSV, batch_size=64, augment_train=False)
print("===== sanity =====")
check_initial_loss(Model(), va)
overfit_small_batch(Model(), tr, steps=200)
check_gradients(Model(), tr)

tr, va = get_loaders(CSV, batch_size=64, augment_train=augment)
print(f"\n===== train {run_name} =====")
train(Model(), tr, va, config, run_name=run_name)
# Out:
# ===== sanity =====
# initial loss = 1.940, expected ~1.946
# step   0 | loss 2.0019 | acc 0.141
# step  50 | loss 0.0078 | acc 1.000
# step 100 | loss 0.0027 | acc 1.000
# step 150 | loss 0.0013 | acc 1.000
# step 199 | loss 0.0010 | acc 1.000
# features.0.0.weight                      grad norm = 0.856823
# features.0.0.bias                        grad norm = 0.000014
# features.0.1.weight                      grad norm = 0.102145
# features.0.1.bias                        grad norm = 0.100897
# features.0.3.weight                      grad norm = 4.164907
# features.0.3.bias                        grad norm = 0.000001
# features.0.4.weight                      grad norm = 0.105859
# features.0.4.bias                        grad norm = 0.085511
# features.1.0.weight                      grad norm = 3.738936
# features.1.0.bias                        grad norm = 0.000000
# features.1.1.weight                      grad norm = 0.068021
# features.1.1.bias                        grad norm = 0.063391
# features.1.3.weight                      grad norm = 4.343399
# features.1.3.bias                        grad norm = 0.000000
# features.1.4.weight                      grad norm = 0.075055
# features.1.4.bias                        grad norm = 0.050327
# features.2.0.weight                      grad norm = 4.396737
# features.2.0.bias                        grad norm = 0.000000
# features.2.1.weight                      grad norm = 0.062323
# features.2.1.bias                        grad norm = 0.056318
# features.2.3.weight                      grad norm = 5.230230
# features.2.3.bias                        grad norm = 0.000000
# features.2.4.weight                      grad norm = 0.063429
# features.2.4.bias                        grad norm = 0.040472
# classifier.1.weight                      grad norm = 10.380928
# classifier.1.bias                        grad norm = 0.000000
# classifier.2.weight                      grad norm = 0.059554
# classifier.2.bias                        grad norm = 0.060323
# classifier.5.weight                      grad norm = 2.486169
# classifier.5.bias                        grad norm = 0.135229
#
# ===== train 03_regularized_cnn =====
# Finishing previous runs because reinit is set to True.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁</td></tr><tr><td>overfit_gap</td><td>▁</td></tr><tr><td>train_acc</td><td>▁</td></tr><tr><td>train_loss</td><td>▁</td></tr><tr><td>val_acc</td><td>▁</td></tr><tr><td>val_loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>0</td></tr><tr><td>overfit_gap</td><td>-0.08319</td></tr><tr><td>train_acc</td><td>0.39205</td></tr><tr><td>train_loss</td><td>1.56007</td></tr><tr><td>val_acc</td><td>0.47524</td></tr><tr><td>val_loss</td><td>1.37815</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">03_regularized_cnn</strong> at: <a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments/runs/01l9s7fk' target="_blank">https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments/runs/01l9s7fk</a><br> View project at: <a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments' target="_blank">https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260615_153830-01l9s7fk\logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>D:\ML\project4\ML_Wandb\wandb\run-20260615_155428-x0oe2r24</code>
# Syncing run <strong><a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments/runs/x0oe2r24' target="_blank">03_regularized_cnn</a></strong> to <a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments' target="_blank">https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments</a>
#  View run at <a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments/runs/x0oe2r24' target="_blank">https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments/runs/x0oe2r24</a>
# epoch  0 | train 1.537/0.403 | val 1.468/0.446 | gap -0.043
# epoch  1 | train 1.258/0.516 | val 1.247/0.530 | gap -0.013
# epoch  2 | train 1.167/0.554 | val 1.183/0.563 | gap -0.010
# epoch  3 | train 1.098/0.585 | val 1.115/0.574 | gap +0.010
# epoch  4 | train 1.042/0.604 | val 1.137/0.578 | gap +0.025
# epoch  5 | train 0.996/0.622 | val 1.103/0.593 | gap +0.029
# epoch  6 | train 0.951/0.641 | val 1.088/0.592 | gap +0.049
# epoch  7 | train 0.905/0.659 | val 1.070/0.608 | gap +0.051
# epoch  8 | train 0.863/0.673 | val 1.045/0.627 | gap +0.046
# epoch  9 | train 0.825/0.694 | val 1.051/0.618 | gap +0.075
# epoch 10 | train 0.774/0.711 | val 1.082/0.631 | gap +0.080
# epoch 11 | train 0.733/0.728 | val 1.065/0.622 | gap +0.106
# epoch 12 | train 0.685/0.747 | val 1.062/0.626 | gap +0.121
# epoch 13 | train 0.644/0.761 | val 1.085/0.635 | gap +0.126
# epoch 14 | train 0.603/0.774 | val 1.079/0.643 | gap +0.132
# epoch 15 | train 0.559/0.795 | val 1.137/0.634 | gap +0.161
# epoch 16 | train 0.522/0.808 | val 1.148/0.630 | gap +0.177
# epoch 17 | train 0.483/0.823 | val 1.161/0.639 | gap +0.184
# epoch 18 | train 0.448/0.833 | val 1.185/0.644 | gap +0.189
# epoch 19 | train 0.423/0.846 | val 1.215/0.628 | gap +0.217
# epoch 20 | train 0.382/0.859 | val 1.244/0.647 | gap +0.212
# epoch 21 | train 0.369/0.867 | val 1.256/0.638 | gap +0.228
# epoch 22 | train 0.349/0.874 | val 1.269/0.649 | gap +0.225
# epoch 23 | train 0.324/0.882 | val 1.280/0.644 | gap +0.238
# epoch 24 | train 0.301/0.890 | val 1.362/0.643 | gap +0.248
# epoch 25 | train 0.287/0.897 | val 1.323/0.655 | gap +0.242
# epoch 26 | train 0.274/0.905 | val 1.371/0.654 | gap +0.250
# epoch 27 | train 0.261/0.905 | val 1.389/0.649 | gap +0.256
# epoch 28 | train 0.250/0.909 | val 1.413/0.653 | gap +0.256
# epoch 29 | train 0.240/0.917 | val 1.438/0.644 | gap +0.273
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>overfit_gap</td><td>▁▂▂▂▃▃▃▃▃▄▄▄▅▅▅▆▆▆▆▇▇▇▇▇▇▇████</td></tr><tr><td>train_acc</td><td>▁▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇███████</td></tr><tr><td>train_loss</td><td>█▆▆▆▅▅▅▅▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▄▅▅▅▆▆▆▇▇▇▇▇▇█▇▇▇█▇█▇████████</td></tr><tr><td>val_loss</td><td>█▄▃▂▃▂▂▁▁▁▂▁▁▂▂▃▃▃▃▄▄▄▅▅▆▆▆▇▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acc_Angry</td><td>0.53383</td></tr><tr><td>acc_Disgust</td><td>0.51163</td></tr><tr><td>acc_Fear</td><td>0.43765</td></tr><tr><td>acc_Happy</td><td>0.86963</td></tr><tr><td>acc_Neutral</td><td>0.61694</td></tr><tr><td>acc_Sad</td><td>0.59213</td></tr><tr><td>acc_Surprise</td><td>0.77287</td></tr><tr><td>best_val_acc</td><td>0.65481</td></tr><tr><td>epoch</td><td>29</td></tr><tr><td>overfit_gap</td><td>0.27283</td></tr><tr><td>+5</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">03_regularized_cnn</strong> at: <a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments/runs/x0oe2r24' target="_blank">https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments/runs/x0oe2r24</a><br> View project at: <a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments' target="_blank">https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments</a><br>Synced 4 W&B file(s), 1 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260615_155428-x0oe2r24\logs</code>
# (RegularizedCNN(
#    (features): Sequential(
#      (0): Sequential(
#        (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#        (2): ReLU()
#        (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#        (5): ReLU()
#        (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#        (7): Dropout(p=0.4, inplace=False)
#      )
#      (1): Sequential(
#        (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#        (2): ReLU()
#        (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#        (5): ReLU()
#        (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#        (7): Dropout(p=0.4, inplace=False)
#      )
#      (2): Sequential(
#        (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#        (2): ReLU()
#        (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#        (5): ReLU()
#        (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#        (7): Dropout(p=0.4, inplace=False)
#      )
#    )
#    (classifier): Sequential(
#      (0): Flatten(start_dim=1, end_dim=-1)
#      (1): Linear(in_features=9216, out_features=512, bias=True)
#      (2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#      (3): ReLU()
#      (4): Dropout(p=0.4, inplace=False)
#      (5): Linear(in_features=512, out_features=7, bias=True)
#    )
#  ),
#  0.6548117154811716)
