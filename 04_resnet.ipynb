# %%
import importlib
import src.data, src.models, src.utils, src.train
for _m in (src.data, src.models, src.utils, src.train):
    importlib.reload(_m)

import os
from src.data import get_loaders
from src.models import ResNetMini
from src.utils import check_initial_loss, overfit_small_batch, check_gradients
from src.train import train

CSV = '../train.csv'
print('Using data:', CSV)

Model    = ResNetMini
run_name = '04_resnet'
config   = {'lr':1e-3,'epochs':30,'optimizer':'adam'}
augment  = False

tr, va = get_loaders(CSV, batch_size=64, augment_train=False)
print("===== sanity =====")
check_initial_loss(Model(), va)
overfit_small_batch(Model(), tr, steps=200)
check_gradients(Model(), tr)

tr, va = get_loaders(CSV, batch_size=64, augment_train=augment)
print(f"\n===== train {run_name} =====")
train(Model(), tr, va, config, run_name=run_name)
# Out:
# Using data: ../train.csv
# ===== sanity =====
# initial loss = 1.940, expected ~1.946
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 28
#      24 check_gradients(Model(), tr)
#      25
#      26 tr, va = get_loaders(CSV, batch_size=64, augment_train=augment)
#      27 print(f"\n===== train {run_name} =====")
# ---> 28 train(Model(), tr, va, config, run_name=run_name)
#
# File D:\ML\project4\ML_Wandb\src\train.py:55, in train(model, train_loader, val_loader, config, project, run_name, test_loader)
#      53 x, y = x.to(DEVICE), y.to(DEVICE)
#      54 optimizer.zero_grad()
# ---> 55 out = model(x)
#      56 loss = criterion(out, y)
#      57 loss.backward()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File D:\ML\project4\ML_Wandb\src\models.py:83, in forward(self, x)
#      77 def __init__(self, num_classes=7, dropout=0.5):
#      78     super().__init__()
#      79     self.features = nn.Sequential(
#      80         nn.Conv2d(1, 64, 3, padding=1), nn.ReLU(inplace=True), nn.MaxPool2d(2),
#      81         nn.Conv2d(64, 192, 3, padding=1), nn.ReLU(inplace=True), nn.MaxPool2d(2),
#      82         nn.Conv2d(192, 384, 3, padding=1), nn.ReLU(inplace=True),
# ---> 83         nn.Conv2d(384, 256, 3, padding=1), nn.ReLU(inplace=True),
#      84         nn.Conv2d(256, 256, 3, padding=1), nn.ReLU(inplace=True), nn.MaxPool2d(2),
#      85     )
#      86     self.classifier = nn.Sequential(
#      87         nn.Flatten(),
#      88         nn.Dropout(dropout), nn.Linear(256 * 6 * 6, 4096), nn.ReLU(inplace=True),
#      89         nn.Dropout(dropout), nn.Linear(4096, 4096), nn.ReLU(inplace=True),
#      90         nn.Linear(4096, num_classes),
#      91     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File D:\ML\project4\ML_Wandb\src\models.py:66, in forward(self, x)
#      63 super().__init__()
#      64 self.stem = nn.Sequential(
#      65     nn.Conv2d(1, 64, 3, 1, 1, bias=False), nn.BatchNorm2d(64), nn.ReLU(inplace=True))
# ---> 66 self.layer1 = nn.Sequential(_ResBlock(64, 64), _ResBlock(64, 64))
#      67 self.layer2 = nn.Sequential(_ResBlock(64, 128, 2), _ResBlock(128, 128))
#      68 self.layer3 = nn.Sequential(_ResBlock(128, 256, 2), _ResBlock(256, 256))
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\conv.py:565, in Conv2d.forward(self, input)
#     564 def forward(self, input: Tensor) -> Tensor:
# --> 565     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\conv.py:560, in Conv2d._conv_forward(self, input, weight, bias)
#     547 if self.padding_mode != "zeros":
#     548     return F.conv2d(
#     549         F.pad(
#     550             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    557         self.groups,
#     558     )
# --> 560 return F.conv2d(
#     561     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     562 )
#
# KeyboardInterrupt:
