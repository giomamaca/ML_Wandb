# %%
import os
from src.data import get_loaders
from src.models import SmallCNN
from src.utils import check_initial_loss, overfit_small_batch, check_gradients
from src.train import train

CSV =  '../train.csv'
print('Using data:', CSV)

Model    = SmallCNN
run_name = '02_small_cnn'
config   = {'lr':1e-3,'epochs':30,'optimizer':'adam'}
augment  = False

tr, va = get_loaders(CSV, batch_size=64, augment_train=False)
print("===== sanity =====")
check_initial_loss(Model(), va)
overfit_small_batch(Model(), tr, steps=200)
check_gradients(Model(), tr)

tr, va = get_loaders(CSV, batch_size=64, augment_train=augment)
print(f"\n===== train {run_name} =====")
train(Model(), tr, va, config, run_name=run_name)
# Out:
# Using data: ../train.csv
# ===== sanity =====
# initial loss = 1.961, expected ~1.946
# step   0 | loss 1.9429 | acc 0.172
# step  50 | loss 0.0326 | acc 1.000
# step 100 | loss 0.0003 | acc 1.000
# step 150 | loss 0.0002 | acc 1.000
# step 199 | loss 0.0001 | acc 1.000
# features.0.weight                        grad norm = 0.008115
# features.0.bias                          grad norm = 0.004813
# features.3.weight                        grad norm = 0.050914
# features.3.bias                          grad norm = 0.012364
# features.6.weight                        grad norm = 0.071622
# features.6.bias                          grad norm = 0.034001
# classifier.1.weight                      grad norm = 0.251370
# classifier.1.bias                        grad norm = 0.079203
# classifier.3.weight                      grad norm = 0.069499
# classifier.3.bias                        grad norm = 0.206762
#
# ===== train 02_small_cnn =====
# Finishing previous runs because reinit is set to True.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>overfit_gap</td><td>▁▂▂▂▃▃▃▄▄▅▅▆▆▇▇▇▇█████████████</td></tr><tr><td>train_acc</td><td>▁▂▃▃▄▄▄▅▅▆▆▆▇▇▇▇██████████████</td></tr><tr><td>train_loss</td><td>█▇▆▆▆▅▅▅▄▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▃▅▆▇▇▇█▇███▇▇▇▇█▇▇▇▇▇▇▇▇▇▇▇█▇</td></tr><tr><td>val_loss</td><td>▂▁▁▁▁▁▁▁▁▁▂▂▂▃▃▄▅▅▅▆▆▆▆▆▇▇▇█▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_acc</td><td>0.55474</td></tr><tr><td>epoch</td><td>29</td></tr><tr><td>overfit_gap</td><td>0.44474</td></tr><tr><td>train_acc</td><td>0.97508</td></tr><tr><td>train_loss</td><td>0.07912</td></tr><tr><td>val_acc</td><td>0.53033</td></tr><tr><td>val_acc_best</td><td>0.55474</td></tr><tr><td>val_loss</td><td>4.01852</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">02_small_cnn</strong> at: <a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments/runs/yq9yl3q1' target="_blank">https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments/runs/yq9yl3q1</a><br> View project at: <a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments' target="_blank">https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments</a><br>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260615_053752-yq9yl3q1\logs</code>
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>D:\ML\project4\ML_Wandb\wandb\run-20260615_061333-u65qn2ss</code>
# Syncing run <strong><a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments/runs/u65qn2ss' target="_blank">02_small_cnn</a></strong> to <a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments' target="_blank">https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments</a>
#  View run at <a href='https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments/runs/u65qn2ss' target="_blank">https://wandb.ai/gmama23-free-university-of-tbilisi-/fer2013-experiments/runs/u65qn2ss</a>
# epoch  0 | train 1.702/0.318 | val 1.572/0.394 | gap -0.075
# epoch  1 | train 1.486/0.425 | val 1.451/0.447 | gap -0.022
# epoch  2 | train 1.351/0.481 | val 1.352/0.493 | gap -0.012
# epoch  3 | train 1.244/0.525 | val 1.334/0.497 | gap +0.028
# epoch  4 | train 1.146/0.564 | val 1.301/0.517 | gap +0.047
# epoch  5 | train 1.061/0.600 | val 1.258/0.536 | gap +0.064
# epoch  6 | train 0.966/0.637 | val 1.291/0.541 | gap +0.096
# epoch  7 | train 0.874/0.677 | val 1.295/0.541 | gap +0.136
# epoch  8 | train 0.768/0.720 | val 1.367/0.541 | gap +0.179
# epoch  9 | train 0.662/0.757 | val 1.488/0.547 | gap +0.210
# epoch 10 | train 0.556/0.801 | val 1.611/0.542 | gap +0.258
# epoch 11 | train 0.458/0.836 | val 1.791/0.543 | gap +0.294
# epoch 12 | train 0.360/0.875 | val 1.989/0.533 | gap +0.342
# epoch 13 | train 0.282/0.903 | val 2.115/0.535 | gap +0.369
# epoch 14 | train 0.220/0.927 | val 2.554/0.527 | gap +0.400
# epoch 15 | train 0.170/0.944 | val 2.729/0.524 | gap +0.420
# epoch 16 | train 0.136/0.957 | val 2.824/0.537 | gap +0.421
# epoch 17 | train 0.117/0.964 | val 3.176/0.531 | gap +0.433
# epoch 18 | train 0.097/0.971 | val 3.307/0.528 | gap +0.443
# epoch 19 | train 0.101/0.968 | val 3.493/0.532 | gap +0.436
# epoch 20 | train 0.102/0.967 | val 3.601/0.526 | gap +0.440
# epoch 21 | train 0.102/0.968 | val 3.504/0.534 | gap +0.435
# epoch 22 | train 0.081/0.975 | val 3.733/0.532 | gap +0.443
# epoch 23 | train 0.074/0.978 | val 3.789/0.536 | gap +0.442
# epoch 24 | train 0.072/0.978 | val 3.986/0.532 | gap +0.446
# epoch 25 | train 0.065/0.982 | val 4.145/0.521 | gap +0.461
# epoch 26 | train 0.076/0.977 | val 3.881/0.535 | gap +0.442
# epoch 27 | train 0.071/0.978 | val 4.210/0.532 | gap +0.446
# epoch 28 | train 0.075/0.977 | val 4.088/0.537 | gap +0.440
# epoch 29 | train 0.072/0.977 | val 4.044/0.534 | gap +0.443
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 23
#      19 check_gradients(Model(), tr)
#      20
#      21 tr, va = get_loaders(CSV, batch_size=64, augment_train=augment)
#      22 print(f"\n===== train {run_name} =====")
# ---> 23 train(Model(), tr, va, config, run_name=run_name)
#
# File D:\ML\project4\ML_Wandb\src\train.py:76, in train(model, train_loader, val_loader, config, project, run_name, test_loader)
#      73 _, acc, preds, ys = evaluate(model, eval_loader, criterion, return_preds=True)
#      74 wandb.summary[f'{split}_acc_best'] = acc
# ---> 76 wandb.log({'confusion_matrix': wandb.plot.confusion_matrix(
#      77     preds=preds.tolist(), y_true=ys.tolist(), class_names=EMOTIONS)})
#      79 cm = np.zeros((7,7), dtype=int)                      # per-class accuracy
#      80 for t,p in zip(ys, preds): cm[t,p] += 1
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\wandb\sdk\wandb_run.py:329, in _log_to_run.<locals>.wrapper(self, *args, **kwargs)
#     326     run_id = self._attach_id
#     328 with wb_logging.log_to_run(run_id):
# --> 329     return func(self, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\wandb\sdk\wandb_run.py:387, in _raise_if_finished.<locals>.wrapper_fn(self, *args, **kwargs)
#     384 @functools.wraps(func)
#     385 def wrapper_fn(self: Run, *args: _P.args, **kwargs: _P.kwargs) -> _T:
#     386     if not getattr(self, "_is_finished", False):
# --> 387         return func(self, *args, **kwargs)
#     389     message = (
#     390         f"Run ({self.id}) is finished. The call to"
#     391         f" `{func.__name__}` will be ignored."
#     392         f" Please make sure that you are using an active run."
#     393     )
#     395     raise UsageError(message)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\wandb\sdk\wandb_run.py:374, in _attach.<locals>.wrapper(self, *args, **kwargs)
#     371     finally:
#     372         _is_attaching = ""
# --> 374 return func(self, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\wandb\sdk\wandb_run.py:1998, in Run.log(self, data, step, commit)
#    1991 if self._settings._shared and step is not None:
#    1992     wandb.termwarn(
#    1993         "In shared mode, the use of `wandb.log` with the step argument is not supported "
#    1994         f"and will be ignored. Please refer to {url_registry.url('define-metric')} "
#    1995         "on how to customize your x-axis.",
#    1996         repeat=False,
#    1997     )
# -> 1998 self._log(data=data, step=step, commit=commit)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\wandb\sdk\wandb_run.py:1709, in Run._log(self, data, step, commit)
#    1706 if any(not isinstance(key, str) for key in data):
#    1707     raise TypeError("Key values passed to `wandb.log` must be strings.")
# -> 1709 self._partial_history_callback(data, step, commit)
#    1711 if step is not None:
#    1712     if os.getpid() != self._init_pid or self._is_attached:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\wandb\sdk\wandb_run.py:329, in _log_to_run.<locals>.wrapper(self, *args, **kwargs)
#     326     run_id = self._attach_id
#     328 with wb_logging.log_to_run(run_id):
# --> 329     return func(self, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\wandb\sdk\wandb_run.py:1540, in Run._partial_history_callback(self, data, step, commit)
#    1537 data = self._serialize_custom_charts(data)
#    1539 not_using_tensorboard = len(wandb.patched["tensorboard"]) == 0
# -> 1540 self._interface.publish_partial_history(
#    1541     self,
#    1542     data,
#    1543     user_step=self._local_step,
#    1544     step=step,
#    1545     flush=commit,
#    1546     publish_step=not_using_tensorboard,
#    1547 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\wandb\sdk\interface\interface.py:694, in InterfaceBase.publish_partial_history(self, run, data, user_step, step, flush, publish_step)
#     685 def publish_partial_history(
#     686     self,
#     687     run: Run,
#    (...)    692     publish_step: bool = True,
#     693 ) -> None:
# --> 694     data = history_dict_to_json(run, data, step=user_step, ignore_copy_err=True)
#     695     data.pop("_step", None)
#     697     # add timestamp to the history request, if not already present
#     698     # the timestamp might come from the tensorboard log logic
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\wandb\sdk\data_types\utils.py:57, in history_dict_to_json(run, payload, step, ignore_copy_err)
#      53         payload[key] = history_dict_to_json(
#      54             run, val, step=step, ignore_copy_err=ignore_copy_err
#      55         )
#      56     else:
# ---> 57         payload[key] = val_to_json(
#      58             run, key, val, namespace=step, ignore_copy_err=ignore_copy_err
#      59         )
#      61 return payload
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\wandb\sdk\data_types\utils.py:161, in val_to_json(run, key, val, namespace, ignore_copy_err)
#     156     # Partitioned tables and joined tables do not support being bound to runs.
#     157     if not (
#     158         hasattr(val, "_log_type")
#     159         and val._log_type in ["partitioned-table", "joined-table"]
#     160     ):
# --> 161         val.bind_to_run(run, key, namespace)
#     163 res = val.to_json(run)
#     165 if isinstance(val, wandb.Table) and val.log_mode == "INCREMENTAL":
#     166     # Set the _last_logged_idx AFTER the Table has been logged and
#     167     # bound to the run.
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\wandb\sdk\data_types\table.py:607, in Table.bind_to_run(self, *args, **kwargs)
#     605 tmp_path = os.path.join(MEDIA_TMP.name, runid.generate_id() + ".table.json")
#     606 data = _numpy_arrays_to_lists(data)
# --> 607 with codecs.open(tmp_path, "w", encoding="utf-8") as fp:
#     608     util.json_dump_safer(data, fp)
#     609 self._set_file(tmp_path, is_tmp=True, extension=".table.json")
#
# File <frozen codecs>:921, in open(filename, mode, encoding, errors, buffering)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\User\\AppData\\Local\\Temp\\tmpxj0n8ubuwandb-media\\u4x92eyh.table.json'
