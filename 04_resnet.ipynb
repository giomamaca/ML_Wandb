# %%
import importlib
import src.data, src.models, src.utils, src.train
for _m in (src.data, src.models, src.utils, src.train):
    importlib.reload(_m)

import os
from src.data import get_loaders
from src.models import ResNetMini
from src.utils import check_initial_loss, overfit_small_batch, check_gradients
from src.train import train

CSV = '../train.csv'
print('Using data:', CSV)

Model    = ResNetMini
run_name = '04_resnet'
config   = {'lr':1e-3,'epochs':30,'optimizer':'adam'}
augment  = False

tr, va = get_loaders(CSV, batch_size=64, augment_train=False)
print("===== sanity =====")
check_initial_loss(Model(), va)
overfit_small_batch(Model(), tr, steps=200)
check_gradients(Model(), tr)

tr, va = get_loaders(CSV, batch_size=64, augment_train=augment)
print(f"\n===== train {run_name} =====")
train(Model(), tr, va, config, run_name=run_name)
# Out:
# Using data: ../train.csv
# ===== sanity =====
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x00000299D80B05E0>
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py", line 1686, in __del__
#     self._shutdown_workers()
#   File "C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py", line 1650, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\popen_spawn_win32.py", line 114, in wait
#     res = _winapi.WaitForSingleObject(int(self._handle), msecs)
# KeyboardInterrupt:
# initial loss = 1.945, expected ~1.946
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 23
#      19
#      20 tr, va = get_loaders(CSV, batch_size=64, augment_train=False)
#      21 print("===== sanity =====")
#      22 check_initial_loss(Model(), va)
# ---> 23 overfit_small_batch(Model(), tr, steps=200)
#      24 check_gradients(Model(), tr)
#      25
#      26 tr, va = get_loaders(CSV, batch_size=64, augment_train=augment)
#
# File D:\ML\project4\ML_Wandb\src\utils.py:16, in overfit_small_batch(model, loader, steps, lr)
#      14 def overfit_small_batch(model, loader, steps=200, lr=1e-3):
#      15     model = model.to(DEVICE).train()
# ---> 16     x, y = next(iter(loader))
#      17     x, y = x[:64].to(DEVICE), y[:64].to(DEVICE)
#      18     opt = torch.optim.Adam(model.parameters(), lr=lr)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:498, in DataLoader.__iter__(self)
#     496     return self._iterator
#     497 else:
# --> 498     return self._get_iterator()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:431, in DataLoader._get_iterator(self)
#     429 else:
#     430     self.check_worker_number_rationality()
# --> 431     return _MultiProcessingDataLoaderIter(self)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:1169, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1166 from pickle import PicklingError
#    1168 try:
# -> 1169     w.start()
#    1170 except (TypeError, AttributeError, PicklingError):
#    1171     warnings.warn(
#    1172         "Got pickle error when attempting to start a worker Process. "
#    1173         "This might be because the worker Process arguments are not picklable. "
#    (...)   1177         stacklevel=2,
#    1178     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\context.py:337, in SpawnProcess._Popen(process_obj)
#     334 @staticmethod
#     335 def _Popen(process_obj):
#     336     from .popen_spawn_win32 import Popen
# --> 337     return Popen(process_obj)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\popen_spawn_win32.py:97, in Popen.__init__(self, process_obj)
#      95 try:
#      96     reduction.dump(prep_data, to_child)
# ---> 97     reduction.dump(process_obj, to_child)
#      98 finally:
#      99     set_spawning_popen(None)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\multiprocessing\reduction.py:60, in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#
# KeyboardInterrupt:
